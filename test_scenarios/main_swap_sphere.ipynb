# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from jmetal.problem.singleobjective.unconstrained import Sphere
from runners.single import MultiAgentRunner
from runners.statistic import StatisticRunner
from communication.types import CommuncationWithMutation
from communication.operators import average_operator, swap_operator
import inicialization.agents_inicialization as init



problem = Sphere(number_of_variables = 500)
Agents, Agent_Reference = init.create_agents_float_solution(10, problem, CommuncationWithMutation(operator=swap_operator))

runner = MultiAgentRunner(agents= Agents, agent_single= Agent_Reference)

Statistic_runner = StatisticRunner(runner)


Statistic_runner.run_an_collect_data(no_runs = 1, cycles=100, cycle_iter=25, num_of_comm=6)
Statistic_runner.plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\AlgEvloucyny\Algorytm-stadny\test_scenarios\main_swap_sphere.ipynb Cell 1' in <cell line: 25>()
#      <a href='vscode-notebook-cell:/c%3A/AlgEvloucyny/Algorytm-stadny/test_scenarios/main_swap_sphere.ipynb#ch0000000?line=20'>21</a> Statistic_runner = StatisticRunner(runner)
#      <a href='vscode-notebook-cell:/c%3A/AlgEvloucyny/Algorytm-stadny/test_scenarios/main_swap_sphere.ipynb#ch0000000?line=23'>24</a> Statistic_runner.run_an_collect_data(no_runs = 1, cycles=100, cycle_iter=25, num_of_comm=6)
# ---> <a href='vscode-notebook-cell:/c%3A/AlgEvloucyny/Algorytm-stadny/test_scenarios/main_swap_sphere.ipynb#ch0000000?line=24'>25</a> Statistic_runner.plot()
#
# File c:\AlgEvloucyny\Algorytm-stadny\src\StatisticRunner.py:27, in StatisticRunner.plot(self)
# ...
