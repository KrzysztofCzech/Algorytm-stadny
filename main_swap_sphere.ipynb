# %%
from Evolutionary_algorithm import EvolutionAlgoritm
from jmetal.operator import SBXCrossover, PolynomialMutation, BinaryTournamentSelection
from jmetal.problem.singleobjective.unconstrained import Rastrigin, Sphere
from jmetal.util.termination_criterion import StoppingByEvaluations
from Island import Island
from Agent import Agent
from Executor import MultiAgentRunner
from communication import AttiduteType
from StatisticRunner import StatisticRunner
from communication import CommuncationWithMutation
from communication_operators import average_operator, swap_operator
import inicialization as init

problem = Sphere(number_of_variables = 400)
Agents, Agent_Reference = init.create_agents_float_solution(10, problem, CommuncationWithMutation(operator=swap_operator))

runner = MultiAgentRunner(agents= Agents, agent_single= Agent_Reference)

Statistic_runner = StatisticRunner(runner)


Statistic_runner.run_an_collect_data(no_runs = 10, cycles=100, cycle_iter=30, num_of_comm=6)
Statistic_runner.plot()
# Out:
# Running comparison
# Running comparison
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\AlgEvloucyny\Algorytm-stadny\main_swap_sphere.ipynb Cell 1' in <cell line: 22>()
#      <a href='vscode-notebook-cell:/c%3A/AlgEvloucyny/Algorytm-stadny/main_swap_sphere.ipynb#ch0000000?line=16'>17</a> runner = MultiAgentRunner(agents= Agents, agent_single= Agent_Reference)
#      <a href='vscode-notebook-cell:/c%3A/AlgEvloucyny/Algorytm-stadny/main_swap_sphere.ipynb#ch0000000?line=18'>19</a> Statistic_runner = StatisticRunner(runner)
# ---> <a href='vscode-notebook-cell:/c%3A/AlgEvloucyny/Algorytm-stadny/main_swap_sphere.ipynb#ch0000000?line=21'>22</a> Statistic_runner.run_an_collect_data(no_runs = 15, cycles=150, cycle_iter=40, num_of_comm=6)
#      <a href='vscode-notebook-cell:/c%3A/AlgEvloucyny/Algorytm-stadny/main_swap_sphere.ipynb#ch0000000?line=22'>23</a> Statistic_runner.plot()
#
# File c:\AlgEvloucyny\Algorytm-stadny\StatisticRunner.py:38, in StatisticRunner.run_an_collect_data(self, no_runs, cycles, cycle_iter, num_of_comm)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/StatisticRunner.py?line=35'>36</a> for i in range(no_runs):
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/StatisticRunner.py?line=36'>37</a>     self.Executor.initalize()
# ---> <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/StatisticRunner.py?line=37'>38</a>     self.Executor.run(cycles, cycle_iter, num_of_comm)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/StatisticRunner.py?line=38'>39</a>     self.history.add_data(*self.Executor.get_results(),max((int((cycles * cycle_iter)/30),1) ), len(self.Executor.get_agents()))
#
# File c:\AlgEvloucyny\Algorytm-stadny\Executor.py:48, in MultiAgentRunner.run(self, cycles, cycle_iter, num_of_comm)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Executor.py?line=44'>45</a>     self.communicate(num_of_comm)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Executor.py?line=46'>47</a> print("Running comparison")
# ---> <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Executor.py?line=47'>48</a> self.run_comparison()
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Executor.py?line=49'>50</a> self.plot_results()
#
# File c:\AlgEvloucyny\Algorytm-stadny\Executor.py:60, in MultiAgentRunner.run_comparison(self)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Executor.py?line=57'>58</a> def run_comparison(self):
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Executor.py?line=58'>59</a>     all_iterations = sum([agent.get_num_of_iteration() for agent in self.__agents])
# ---> <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Executor.py?line=59'>60</a>     self._agent_single.run(all_iterations)
#
# File c:\AlgEvloucyny\Algorytm-stadny\Agent.py:21, in Agent.run(self, iterations)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Agent.py?line=19'>20</a> def run(self, iterations):
# ---> <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Agent.py?line=20'>21</a>     self.Island.run(iterations)
#
# File c:\AlgEvloucyny\Algorytm-stadny\Island.py:40, in Island.run(self, iterations)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Island.py?line=37'>38</a> def run(self,iterations):
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Island.py?line=38'>39</a>     for i in range(0,iterations):
# ---> <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Island.py?line=39'>40</a>         self.algorithm.step()
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Island.py?line=40'>41</a>         self.algorithm.update_progress()
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Island.py?line=41'>42</a>         self.update_history()
#
# File c:\PracProb\venv\lib\site-packages\jmetal\core\algorithm.py:145, in EvolutionaryAlgorithm.step(self)
#     <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/core/algorithm.py?line=142'>143</a> def step(self):
#     <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/core/algorithm.py?line=143'>144</a>     mating_population = self.selection(self.solutions)
# --> <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/core/algorithm.py?line=144'>145</a>     offspring_population = self.reproduction(mating_population)
#     <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/core/algorithm.py?line=145'>146</a>     offspring_population = self.evaluate(offspring_population)
#     <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/core/algorithm.py?line=147'>148</a>     self.solutions = self.replacement(self.solutions, offspring_population)
#
# File c:\AlgEvloucyny\Algorytm-stadny\Evolutionary_algorithm.py:66, in EvolutionAlgoritm.reproduction(self, population)
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Evolutionary_algorithm.py?line=63'>64</a>     for j in range(int(self.offspring_population_size / len(population))):
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Evolutionary_algorithm.py?line=64'>65</a>         new_solution = copy(solution)
# ---> <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Evolutionary_algorithm.py?line=65'>66</a>         offspring_population.append(self.mutation_operator.execute(new_solution))
#      <a href='file:///c%3A/AlgEvloucyny/Algorytm-stadny/Evolutionary_algorithm.py?line=67'>68</a> return offspring_population
#
# File c:\PracProb\venv\lib\site-packages\jmetal\operator\mutation.py:77, in PolynomialMutation.execute(self, solution)
#      <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/operator/mutation.py?line=74'>75</a> else:
#      <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/operator/mutation.py?line=75'>76</a>     xy = 1.0 - delta2
# ---> <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/operator/mutation.py?line=76'>77</a>     val = 2.0 * (1.0 - rnd) + 2.0 * (rnd - 0.5) * (pow(xy, self.distribution_index + 1.0))
#      <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/operator/mutation.py?line=77'>78</a>     deltaq = 1.0 - pow(val, mut_pow)
#      <a href='file:///c%3A/PracProb/venv/lib/site-packages/jmetal/operator/mutation.py?line=79'>80</a> y += deltaq * (yu - yl)
#
# KeyboardInterrupt:
